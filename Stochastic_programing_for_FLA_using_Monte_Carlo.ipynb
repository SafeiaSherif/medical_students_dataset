# %% [markdown]
# <a href="https://colab.research.google.com/github/SafeiaSherif/SafeiaSherif/blob/main/Stochastic_programing_for_FLA_using_Monte_Carlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Facility Location-Allocation Model For Disaster Management**

# %% [markdown]
# **This notebook is to solve a multi-obective constrained mathematical model with the weighted sum method using specific weights for each objective in case of stochastic demand that will be solved by Monte Carlo method.**
#
#
# The model is in the field of disaster management. Let's assume a natural disaster that caused a number of affected areas.
#
# These areas will contain 2 types of **stochastic** demand. The first one is the victims' demand(people who need medical support) and the second one is the non-victims' demand(people who need living
# material support).
#
#
# *   The victims' demand will be satisfied by hospitals and temporary emergency centers
# *   The non-victims' demand will be satisfied by shelters.
#
#
# *   The previous facilities(hospitals, centers and shelters) will need resources to serve their demand. So, it is important to add warehouses for the facilities demand.
#
#
# Then, we have number of facilities need to be located and different demands need to be allocated. This problem will be solved to optimize 5 objectives subject to some constraints.
#
# **The objectives are:**
#
# *   Maximize the total covered population by hospitals, centers and shelters.
# *   Minimize the total distances between the affected areas and the facilities.
# *   Maximize the total satisfied resources' demand by warehouses.
# *   Minimize the total distances between warehouses and the other facilities.
# *   Minimize the total located facilities to minimize the cost.
#
# **The main contraints:**
#
# *   Budget constraints.
# *   Capacities constraints.
# *   Service distance constraints.
#
# **Mathematical formulation and illustrative figures:**
#
# https://docs.google.com/document/d/1f3Y7rZNJTPW-5FSfTnqebAyqIGR5AkoEoYmtPYpHUqc/edit?usp=sharing

# %%
import pandas as pd
import numpy as np
from itertools import product
import math

# %% [markdown]
# **Here I specify the limits or the right hand side of the constraints**
#
# *   The capacities of the facilities.
# *   The population of the affected areas.
# *   The severity of the disaster (percentage of victims) for each zone.
# *   Units of resources needed by one victim and so for the non-victim.
# *   Maximum service distances for each kind of facilities.
# *   Maximum allowed number of located facilities for each kind of facilities.

# %%
Cap_H = np.array([750,230])
Cap_C = np.array([100,60])
Cap_SH = np.array([700,600])
Cap_V_W = np.array([300,1000])
Cap_NV_W = np.array([1000,600])

a = np.array([1000,1000,1000])

# %%
U_R_V = 2
U_R_NV = 2

max_D_H = 40
max_D_C = 40
max_D_SH = 40
max_D_W = 40

N = 1
M = 2
Q = 2
S = 10000  # This is the number of scenarios of the stochastic demand

# %% [markdown]
# Function to generate uniform random number on range [0, 1]

# %%
# To generate random values for the parameter p
def p():
  p = np.random.rand()
  return p

# %%
# !pip install gurobipy
import gurobipy as gp
from gurobipy import GRB
# Out:
# Collecting gurobipy
#   Downloading gurobipy-10.0.2-cp310-cp310-manylinux2014_x86_64.whl (12.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 69.3 MB/s eta 0:00:00
# Installing collected packages: gurobipy
# Successfully installed gurobipy-10.0.2

# %%
num_hospitals = len(Cap_H)
num_centers = len(Cap_C)
num_shelters = len(Cap_SH)
num_nodes = len(a)
num_warehouses = len(Cap_V_W)

cartesian_prod_hos = list(product(range(num_hospitals), range(num_nodes)))
cartesian_prod_cntr = list(product(range(num_centers), range(num_nodes)))
cartesian_prod_shltr = list(product(range(num_shelters), range(num_nodes)))
cartesian_prod_warehouse_H = list(product(range(num_warehouses), range(num_hospitals)))
cartesian_prod_warehouse_C = list(product(range(num_warehouses), range(num_centers)))
cartesian_prod_warehouse_SH = list(product(range(num_warehouses), range(num_shelters)))

# %%
scl = 19 # scaling parameter used to scale the distances to suitable values in Km

# %% [markdown]
# As in the mathematical model, we need to assume some parameters and constraints.
# The next part contain those assumbtions.
#
# We assumed 3 disaster zones, 2 valid hospitals, 2 potential places for centers, 2 potential places for shelters and 2 potential places for warehouses.
#
#
# *   Each facility and each zone has (x, y) location.
# *   I used the role of the distance between 2 points to calculate the distances between each facility and each disaster zone.

# %%
i1 = [-0.8, 0.8]
i2 = [1.6, 1.6]
i3 = [1.2, -0.6]

j1 = [1.3, 0.5]
j2 = [0.4, 1.3]

k1 = [2.05, 0.3]
k2 = [-0.13, -0.23]

f1 = [0.42, 0.45]
f2 = [1.85, 0.65]

z1 = [0.4, 0.2]
z2 = [0.83, 1.3]

# %% [markdown]
# Here I calculate the 2d matrix of the distances between the hospitals and the disaster zones

# %%
D_H = [0]*6

D_H[0] = math.sqrt((i1[0]-j1[0])**2+(i1[1]-j1[1])**2)
D_H[1] = math.sqrt((i2[0]-j1[0])**2+(i2[1]-j1[1])**2)
D_H[2] = math.sqrt((i3[0]-j1[0])**2+(i3[1]-j1[1])**2)
D_H[3] = math.sqrt((i1[0]-j2[0])**2+(i1[1]-j2[1])**2)
D_H[4] = math.sqrt((i2[0]-j2[0])**2+(i2[1]-j2[1])**2)
D_H[5] = math.sqrt((i3[0]-j2[0])**2+(i3[1]-j2[1])**2)

D_H = np.array(D_H).reshape(2, 3)

D_H = D_H*scl
D_H = D_H.astype(int)
D_H
# Out:
# array([[40, 21, 20],
#        [24, 23, 39]])

# %% [markdown]
# Here I calculate the 2d matrix of the distances between the centers and the disaster zones

# %%
D_C = [0]*6

D_C[0] = math.sqrt((i1[0]-k1[0])**2+(i1[1]-k1[1])**2)
D_C[1] = math.sqrt((i2[0]-k1[0])**2+(i2[1]-k1[1])**2)
D_C[2] = math.sqrt((i3[0]-k1[0])**2+(i3[1]-k1[1])**2)
D_C[3] = math.sqrt((i1[0]-k2[0])**2+(i1[1]-k2[1])**2)
D_C[4] = math.sqrt((i2[0]-k2[0])**2+(i2[1]-k2[1])**2)
D_C[5] = math.sqrt((i3[0]-k2[0])**2+(i3[1]-k2[1])**2)

D_C = np.array(D_C).reshape(2, 3)

D_C = D_C*scl
D_C = D_C.astype(int)
D_C
# Out:
# array([[54, 26, 23],
#        [23, 47, 26]])

# %% [markdown]
# Here I calculate the 2d matrix of the distances between the shelters and the disaster zones

# %%
D_SH = [0]*6

D_SH[0] = math.sqrt((i1[0]-f1[0])**2+(i1[1]-f1[1])**2)
D_SH[1] = math.sqrt((i2[0]-f1[0])**2+(i2[1]-f1[1])**2)
D_SH[2] = math.sqrt((i3[0]-f1[0])**2+(i3[1]-f1[1])**2)
D_SH[3] = math.sqrt((i1[0]-f2[0])**2+(i1[1]-f2[1])**2)
D_SH[4] = math.sqrt((i2[0]-f2[0])**2+(i2[1]-f2[1])**2)
D_SH[5] = math.sqrt((i3[0]-f2[0])**2+(i3[1]-f2[1])**2)

D_SH = np.array(D_SH).reshape(2, 3)

D_SH = D_SH*scl
D_SH = D_SH.astype(int)
D_SH
# Out:
# array([[24, 31, 24],
#        [50, 18, 26]])

# %% [markdown]
# Here I calculate the 2d matrix of the distances between the hospitals and the warehouses

# %%
D_H_W = [0]*4

D_H_W[0] = math.sqrt((z1[0]-j1[0])**2+(z1[1]-j1[1])**2)
D_H_W[1] = math.sqrt((z2[0]-j1[0])**2+(z2[1]-j1[1])**2)
D_H_W[2] = math.sqrt((z1[0]-j2[0])**2+(z1[1]-j2[1])**2)
D_H_W[3] = math.sqrt((z2[0]-j2[0])**2+(z2[1]-j2[1])**2)

D_H_W = np.array(D_H_W).reshape(2, 2)

D_H_W = D_H_W*scl
D_H_W = D_H_W.astype(int)
D_H_W
# Out:
# array([[18, 17],
#        [20,  8]])

# %% [markdown]
# Here I calculate the 2d matrix of the distances between the centers and the warehouses

# %%
D_C_W = [0]*4

D_C_W[0] = math.sqrt((z1[0]-k1[0])**2+(z1[1]-k1[1])**2)
D_C_W[1] = math.sqrt((z2[0]-k1[0])**2+(z2[1]-k1[1])**2)
D_C_W[2] = math.sqrt((z1[0]-k2[0])**2+(z1[1]-k2[1])**2)
D_C_W[3] = math.sqrt((z2[0]-k2[0])**2+(z2[1]-k2[1])**2)

D_C_W = np.array(D_C_W).reshape(2, 2)

D_C_W = D_C_W*scl
D_C_W = D_C_W.astype(int)
D_C_W
# Out:
# array([[31, 29],
#        [12, 34]])

# %% [markdown]
# Here I calculate the 2d matrix of the distances between the shelters and the warehouses

# %%
D_SH_W = [0]*4

D_SH_W[0] = math.sqrt((z1[0]-f1[0])**2+(z1[1]-f1[1])**2)
D_SH_W[1] = math.sqrt((z2[0]-f1[0])**2+(z2[1]-f1[1])**2)
D_SH_W[2] = math.sqrt((z1[0]-f2[0])**2+(z1[1]-f2[1])**2)
D_SH_W[3] = math.sqrt((z2[0]-f2[0])**2+(z2[1]-f2[1])**2)

D_SH_W = np.array(D_SH_W).reshape(2, 2)

D_SH_W = D_SH_W*scl
D_SH_W = D_SH_W.astype(int)
D_SH_W
# Out:
# array([[ 4, 17],
#        [28, 22]])

# %% [markdown]
# Lists to append the 10,000 solutions of the 10,000 scenarios.

# %%
all_hospitals = []
all_centers = []
all_shelters = []
all_warehouses = []

all_demand_satisfied_H = []
all_demand_satisfied_C = []
all_demand_satisfied_SH = []
all_demand_satisfied_H_W = []
all_demand_satisfied_C_W = []
all_demand_satisfied_SH_W = []

all_nodes_assigned_H = []
all_nodes_assigned_C = []
all_nodes_assigned_SH = []
all_nodes_assigned_H_W = []
all_nodes_assigned_C_W = []
all_nodes_assigned_SH_W = []

all_sum_S_D_H = []
all_sum_S_D_C = []
all_sum_S_D_SH = []

all_obj = []
all_victims = []
all_non_victims = []

all_V_shortage = []
all_NV_shortage = []
all_H_W_shortage = []
all_C_W_shortage = []
all_SH_W_shortage = []

# %% [markdown]
# # **Monte Carlo technique**
#
# In this part I coded a for loop to solve the model 10,000 times with 10,000 scenarios. The average of those soltion is considired as the solution of the problem.

# %%
for i in range(0, S):
  percentage = []
  for x in range(0, num_nodes): # Generate random value for each affected node
    percentage.append(p())
    print(percentage)
  percentage = np.array(percentage)
  victim = a * percentage
  print(victim)
  print(percentage)
  victim = np.array(victim).astype(int)
  non_victim = a * (1-percentage)
  non_victim = np.array(non_victim).astype(int)
  all_victims.append(victim)
  all_non_victims.append(non_victim)

  m = gp.Model("ILP")

  # initialize decision variables
  exist_H = m.addVars(num_hospitals,vtype=GRB.BINARY, name="exist_H")
  exist_C = m.addVars(num_centers,vtype=GRB.BINARY, name="exist_C")
  exist_SH = m.addVars(num_shelters,vtype=GRB.BINARY, name="exist_SH")

  S_D_H = m.addVars(cartesian_prod_hos, lb=0, vtype=GRB.INTEGER, name="S_D_H")
  S_D_C = m.addVars(cartesian_prod_cntr, lb=0, vtype=GRB.INTEGER, name="S_D_C")
  S_D_SH = m.addVars(cartesian_prod_shltr, lb=0, vtype=GRB.INTEGER, name="S_D_SH")

  assigned_H = m.addVars(cartesian_prod_hos,vtype=GRB.BINARY, name="assigned_H")
  assigned_C = m.addVars(cartesian_prod_cntr,vtype=GRB.BINARY, name="assigned_C")
  assigned_SH = m.addVars(cartesian_prod_shltr,vtype=GRB.BINARY, name="assigned_SH")

  exist_W = m.addVars(num_warehouses,vtype=GRB.BINARY, name="exist_W")

  S_D_H_W = m.addVars(cartesian_prod_warehouse_H, lb=0, vtype=GRB.INTEGER, name="S_D_H_W")
  S_D_C_W = m.addVars(cartesian_prod_warehouse_C, lb=0, vtype=GRB.INTEGER, name="S_D_C_W")
  S_D_SH_W = m.addVars(cartesian_prod_warehouse_SH, lb=0, vtype=GRB.INTEGER, name="S_D_SH_W")

  assigned_H_W =  m.addVars(cartesian_prod_warehouse_H,vtype=GRB.BINARY, name="assigned_H_W")
  assigned_C_W =  m.addVars(cartesian_prod_warehouse_C,vtype=GRB.BINARY, name="assigned_C_W")
  assigned_SH_W =  m.addVars(cartesian_prod_warehouse_SH,vtype=GRB.BINARY, name="assigned_SH_W")

  sum_S_D_H = m.addVars(num_hospitals, lb=0, vtype=GRB.INTEGER, name="sum_S_D_H")
  sum_S_D_C = m.addVars(num_centers, lb=0, vtype=GRB.INTEGER, name="sum_S_D_C")
  sum_S_D_SH = m.addVars(num_shelters, lb=0, vtype=GRB.INTEGER, name="sum_S_D_SH")

  # add constraints of distances
  m.addConstrs((D_H[(j,i)]*assigned_H[(j,i)] <= max_D_H for j,i in cartesian_prod_hos), name="max_Dis_Hos")
  m.addConstrs((D_C[(k,i)]*assigned_C[(k,i)] <= max_D_C for k,i in cartesian_prod_cntr), name="max_Dis_Cntr")
  m.addConstrs((D_SH[(f,i)]*assigned_SH[(f,i)] <= max_D_SH for f,i in cartesian_prod_shltr), name="max_Dis_Shltr")

  m.addConstrs((D_H_W[(z,j)]*assigned_H_W[(z,j)] <= max_D_W for z,j in cartesian_prod_warehouse_H), name="max_dis_warehouse_Hos")
  m.addConstrs((D_C_W[(z,k)]*assigned_C_W[(z,k)] <= max_D_W for z,k in cartesian_prod_warehouse_C), name="max_dis_warehouse_Cntr")
  m.addConstrs((D_SH_W[(z,f)]*assigned_SH_W[(z,f)] <= max_D_W for z,f in cartesian_prod_warehouse_SH), name="max_dis_warehouse_Shltr")

  m.addConstrs((S_D_H[(j,i)]*assigned_H[(j,i)] == S_D_H[(j,i)] for j,i in cartesian_prod_hos), name="additional_h")
  m.addConstrs((S_D_C[(k,i)]*assigned_C[(k,i)] == S_D_C[(k,i)] for k,i in cartesian_prod_cntr), name="additional_c")
  m.addConstrs((S_D_SH[(f,i)]*assigned_SH[(f,i)] == S_D_SH[(f,i)] for f,i in cartesian_prod_shltr), name="additional_sh")
  m.addConstrs((S_D_H_W[(z,j)]*assigned_H_W[(z,j)] == S_D_H_W[(z,j)] for z,j in cartesian_prod_warehouse_H), name="additional_h_w")
  m.addConstrs((S_D_C_W[(z,k)]*assigned_C_W[(z,k)] == S_D_C_W[(z,k)] for z,k in cartesian_prod_warehouse_C), name="additional_c_w")
  m.addConstrs((S_D_SH_W[(z,f)]*assigned_SH_W[(z,f)] == S_D_SH_W[(z,f)] for z,f in cartesian_prod_warehouse_SH), name="additional_sh_w")

  # add constraints of capacities
  m.addConstrs((gp.quicksum(S_D_H[(j,i)] for i in range(num_nodes)) <= Cap_H[j]*exist_H[j] for j in range(num_hospitals)), name="Cap_Hos")
  m.addConstrs((gp.quicksum(S_D_C[(k,i)] for i in range(num_nodes)) <= Cap_C[k]*exist_C[k] for k in range(num_centers)), name="Cap_Cntr")
  m.addConstrs((gp.quicksum(S_D_SH[(f,i)] for i in range(num_nodes)) <= Cap_SH[f]*exist_SH[f] for f in range(num_shelters)), name="Cap_Shltr")

  m.addConstrs(((gp.quicksum(S_D_H_W[(z,j)] for j in range(num_hospitals)) + gp.quicksum(S_D_C_W[(z,k)] for k in range(num_centers))) <= Cap_V_W[z]*exist_W[z] for z in range(num_warehouses)), name="Cap_warehouse_victim")
  m.addConstrs((gp.quicksum(S_D_SH_W[(z,f)] for f in range(num_shelters)) <= Cap_NV_W[z]*exist_W[z] for z in range(num_warehouses)), name="Cap_warehouse_nonvictim")

  # add constraint to meet the actual demand
  m.addConstrs(((gp.quicksum(S_D_H[(j,i)] for j in range(num_hospitals)) + gp.quicksum(S_D_C[(k,i)] for k in range(num_centers))) <= victim[i] for i in range(num_nodes)), name="acual_victim_demand")
  m.addConstrs((gp.quicksum(S_D_SH[(f,i)] for f in range(num_shelters)) <= non_victim[i] for i in range(num_nodes)), name="acual_non_victim_demand")

  m.addConstrs((gp.quicksum(S_D_H[(j,i)] for i in range(num_nodes)) == sum_S_D_H[j] for j in range(num_hospitals)), name="Sum_S_D_Hos")
  m.addConstrs((gp.quicksum(S_D_C[(k,i)] for i in range(num_nodes)) == sum_S_D_C[k] for k in range(num_centers)), name="Sum_S_D_Cntr")
  m.addConstrs((gp.quicksum(S_D_SH[(f,i)] for i in range(num_nodes)) == sum_S_D_SH[f] for f in range(num_shelters)), name="Sum_S_D_Shltr")


  m.addConstrs((gp.quicksum(S_D_H_W[(z,j)] for z in range(num_warehouses)) <= U_R_V * sum_S_D_H[j]*exist_H[j] for j in range(num_hospitals)), name="satisfy_demand_hospital")
  m.addConstrs((gp.quicksum(S_D_C_W[(z,k)] for z in range(num_warehouses)) <= U_R_V * sum_S_D_C[k]*exist_C[k] for k in range(num_centers)), name="satisfy_demand_Center")
  m.addConstrs((gp.quicksum(S_D_SH_W[(z,f)] for z in range(num_warehouses)) <= U_R_NV * sum_S_D_SH[f]*exist_SH[f] for f in range(num_shelters)), name="satisfy_demand_Shelter")

  # add constraint of limited number of centers, shelters and warehouses
  m.addConstr((gp.quicksum(exist_C) <= N), name="limited_Cntr")
  m.addConstr((gp.quicksum(exist_SH) <= M), name="limited_Shltr")
  m.addConstr((gp.quicksum(exist_W) <= Q), name="limited_WarHouse")

  # Normalization factors
  norm11 = 1/(sum(Cap_H))
  norm12 = 1/(sum(Cap_C))
  norm13 = 1/(sum(Cap_SH))

  norm21 = 1/(sum(sum(D_H)))
  norm22 = 1/(sum(sum(D_C)))
  norm23 = 1/(sum(sum(D_SH)))

  norm31 = 1/(sum(Cap_V_W))
  norm32 = 1/(sum(Cap_V_W))
  norm33 = 1/(sum(Cap_NV_W))

  norm41 = 1/(sum(sum(D_H_W)))
  norm42 = 1/(sum(sum(D_C_W)))
  norm43 = 1/(sum(sum(D_SH_W)))

  norm51 = 1/num_hospitals
  norm52 = 1/N
  norm53 = 1/M
  norm54 = 1/Q
  w = 1/18.1

  # set objective
  m.setObjective(2*w*norm11*(gp.quicksum(S_D_H[(j,i)]*assigned_H[(j,i)] for j,i in cartesian_prod_hos)) + 1.5*w*norm12*(gp.quicksum(S_D_C[(k,i)]*assigned_C[(k,i)] for k,i in cartesian_prod_cntr)) + 2*w*norm13*(gp.quicksum(S_D_SH[(f,i)]*assigned_SH[(f,i)] for f,i in cartesian_prod_shltr))
  - norm21*w*(gp.quicksum(D_H[(j,i)] * assigned_H[(j,i)] for j,i in cartesian_prod_hos)) - norm22*w*(gp.quicksum(D_C[(k,i)]*assigned_C[(k,i)] for k,i in cartesian_prod_cntr )) - norm23*w*(gp.quicksum(D_SH[(f,i)]*assigned_SH[(f,i)] for f,i in cartesian_prod_shltr ))
  + 2*w*norm31*(gp.quicksum(S_D_H_W[(z,j)]*assigned_H_W[(z,j)] for z,j in cartesian_prod_warehouse_H)) + 2*w*norm32*(gp.quicksum(S_D_C_W[(z,k)]*assigned_C_W[(z,k)] for z,k in cartesian_prod_warehouse_C)) + 2*w*norm33*(gp.quicksum(S_D_SH_W[(z,f)]*assigned_SH_W[(z,f)] for z,f in cartesian_prod_warehouse_SH))
  - norm41*w*(gp.quicksum(D_H_W[(z,j)]*assigned_H_W[(z,j)] for z,j in cartesian_prod_warehouse_H)) - norm42*w*(gp.quicksum(D_C_W[(z,k)] * assigned_C_W[(z,k)] for z,k in cartesian_prod_warehouse_C)) - norm43*w*(gp.quicksum(D_SH_W[(z,f)] * assigned_SH_W[(z,f)] for z,f in cartesian_prod_warehouse_SH))
  - 0.2*w*norm51*(gp.quicksum(exist_H)) - 0.2*w*norm52*(gp.quicksum(exist_C)) - 0.1*w*norm53*(gp.quicksum(exist_SH)) - 0.1*w*norm54*(gp.quicksum(exist_W))
  , GRB.MAXIMIZE)

  # optimization of model
  m.optimize()
  # The final answer
  vars = m.getVars() # list of the DVs values

  # Lists to separate each kind of DVs
  hospitals = []
  centers = []
  shelters = []
  warehouses = []

  demand_satisfied_H = []
  demand_satisfied_C = []
  demand_satisfied_SH = []
  demand_satisfied_H_W = []
  demand_satisfied_C_W = []
  demand_satisfied_SH_W = []

  nodes_assigned_H = []
  nodes_assigned_C = []
  nodes_assigned_SH = []
  nodes_assigned_H_W = []
  nodes_assigned_C_W = []
  nodes_assigned_SH_W = []

  sum_demand_satisfied_H = []
  sum_demand_satisfied_C = []
  sum_demand_satisfied_SH = []

  # Separate each kind of DVs and append it to its list
  for j in range(0, num_hospitals):
    hospitals.append(vars[j].X)
  hospitals = np.array(hospitals).astype(int)
  all_hospitals.append(hospitals) # to keep the solution to get the average at the end.

  for k in range(num_hospitals, num_hospitals+num_centers):
    centers.append(vars[k].X)
  centers = np.array(centers).astype(int)
  all_centers.append(centers)

  for f in range(num_hospitals+num_centers, num_hospitals+num_centers+num_shelters):
    shelters.append(vars[f].X)
  shelters = np.array(shelters).astype(int)
  all_shelters.append(shelters)

  for j in range(num_hospitals+num_centers+num_shelters, num_hospitals+num_centers+num_shelters+(num_hospitals*num_nodes)):
    demand_satisfied_H.append(vars[j].X)
  demand_satisfied_H = np.array(demand_satisfied_H).reshape(num_hospitals, num_nodes).astype(int)
  all_demand_satisfied_H.append(demand_satisfied_H)

  for k in range(num_hospitals+num_centers+num_shelters+(num_hospitals*num_nodes), num_hospitals+num_centers+num_shelters+(num_hospitals*num_nodes)+(num_centers*num_nodes)):
    demand_satisfied_C.append(vars[k].X)
  demand_satisfied_C = np.array(demand_satisfied_C).reshape(num_centers, num_nodes).astype(int)
  all_demand_satisfied_C.append(demand_satisfied_C)

  for f in range(num_hospitals+num_centers+num_shelters+(num_hospitals*num_nodes)+(num_centers*num_nodes), num_hospitals+num_centers+num_shelters+(num_hospitals*num_nodes)+(num_centers*num_nodes)+(num_shelters*num_nodes)):
    demand_satisfied_SH.append(vars[f].X)
  demand_satisfied_SH = np.array(demand_satisfied_SH).reshape(num_shelters, num_nodes).astype(int)
  all_demand_satisfied_SH.append(demand_satisfied_SH)

  for j in range(num_hospitals+num_centers+num_shelters+(num_hospitals*num_nodes)+(num_centers*num_nodes)+(num_shelters*num_nodes), num_hospitals+num_centers+num_shelters+(2*num_hospitals*num_nodes)+(num_centers*num_nodes)+(num_shelters*num_nodes)):
    nodes_assigned_H.append(vars[j].X)
  nodes_assigned_H = np.array(nodes_assigned_H).reshape(num_hospitals, num_nodes).astype(int)
  all_nodes_assigned_H.append(nodes_assigned_H)

  for k in range(num_hospitals+num_centers+num_shelters+(2*num_hospitals*num_nodes)+(num_centers*num_nodes)+(num_shelters*num_nodes), num_hospitals+num_centers+num_shelters+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(num_shelters*num_nodes)):
    nodes_assigned_C.append(vars[k].X)
  nodes_assigned_C = np.array(nodes_assigned_C).reshape(num_centers, num_nodes).astype(int)
  all_nodes_assigned_C.append(nodes_assigned_C)

  for f in range(num_hospitals+num_centers+num_shelters+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(num_shelters*num_nodes), num_hospitals+num_centers+num_shelters+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)):
    nodes_assigned_SH.append(vars[f].X)
  nodes_assigned_SH = np.array(nodes_assigned_SH).reshape(num_shelters, num_nodes).astype(int)
  all_nodes_assigned_SH.append(nodes_assigned_SH)

  for z in range(num_hospitals+num_centers+num_shelters+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes), num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)):
    warehouses.append(vars[z].X)
  warehouses = np.array(warehouses).astype(int)
  all_warehouses.append(warehouses)

  for z in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes), num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(num_warehouses*num_hospitals)):
    demand_satisfied_H_W.append(vars[z].X)
  demand_satisfied_H_W = np.array(demand_satisfied_H_W).reshape(num_warehouses, num_hospitals).astype(int)
  all_demand_satisfied_H_W.append(demand_satisfied_H_W)

  for z in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(num_warehouses*num_hospitals),num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(num_warehouses*num_hospitals)+(num_warehouses*num_centers)):
    demand_satisfied_C_W.append(vars[z].X)
  demand_satisfied_C_W = np.array(demand_satisfied_C_W).reshape(num_warehouses, num_centers).astype(int)
  all_demand_satisfied_C_W.append(demand_satisfied_C_W)

  for z in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(num_warehouses*num_hospitals)+(num_warehouses*num_centers),num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(num_warehouses*num_hospitals)+(num_warehouses*num_centers)+(num_warehouses*num_shelters)):
    demand_satisfied_SH_W.append(vars[z].X)
  demand_satisfied_SH_W = np.array(demand_satisfied_SH_W).reshape(num_warehouses, num_shelters).astype(int)
  all_demand_satisfied_SH_W.append(demand_satisfied_SH_W)

  for z in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(num_warehouses*num_hospitals)+(num_warehouses*num_centers)+(num_warehouses*num_shelters), num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(num_warehouses*num_centers)+(num_warehouses*num_shelters)):
    nodes_assigned_H_W.append(vars[z].X)
  nodes_assigned_H_W = np.array(nodes_assigned_H_W).reshape(num_warehouses, num_hospitals).astype(int)
  all_nodes_assigned_H_W.append(nodes_assigned_H_W)

  for z in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(num_warehouses*num_centers)+(num_warehouses*num_shelters), num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(num_warehouses*num_shelters)):
    nodes_assigned_C_W.append(vars[z].X)
  nodes_assigned_C_W = np.array(nodes_assigned_C_W).reshape(num_warehouses, num_centers).astype(int)
  all_nodes_assigned_C_W.append(nodes_assigned_C_W)

  for z in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(num_warehouses*num_shelters), num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(2*num_warehouses*num_shelters)):
    nodes_assigned_SH_W.append(vars[z].X)
  nodes_assigned_SH_W = np.array(nodes_assigned_SH_W).reshape(num_warehouses, num_shelters).astype(int)
  all_nodes_assigned_SH_W.append(nodes_assigned_SH_W)

  for j in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(2*num_warehouses*num_shelters), num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(2*num_warehouses*num_shelters)+num_hospitals):
    sum_demand_satisfied_H.append(vars[j].X)
  sum_demand_satisfied_H = np.array(sum_demand_satisfied_H).astype(int)
  all_sum_S_D_H.append(sum_demand_satisfied_H)

  for k in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(2*num_warehouses*num_shelters)+num_hospitals, num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(2*num_warehouses*num_shelters)+num_hospitals+num_centers):
    sum_demand_satisfied_C.append(vars[k].X)
  sum_demand_satisfied_C = np.array(sum_demand_satisfied_C).astype(int)
  all_sum_S_D_C.append(sum_demand_satisfied_C)

  for f in range(num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(2*num_warehouses*num_shelters)+num_hospitals+num_centers, num_hospitals+num_centers+num_shelters+num_warehouses+(2*num_hospitals*num_nodes)+(2*num_centers*num_nodes)+(2*num_shelters*num_nodes)+(2*num_warehouses*num_hospitals)+(2*num_warehouses*num_centers)+(2*num_warehouses*num_shelters)+num_hospitals+num_centers+num_shelters):
    sum_demand_satisfied_SH.append(vars[f].X)
  sum_demand_satisfied_SH = np.array(sum_demand_satisfied_SH).astype(int)
  all_sum_S_D_SH.append(sum_demand_satisfied_SH)

  all_V_shortage.append(sum(victim)-(sum(sum(demand_satisfied_H))+sum(sum(demand_satisfied_C))))
  all_NV_shortage.append(sum(non_victim)-sum(sum(demand_satisfied_SH)))
  all_H_W_shortage.append(U_R_V*sum(sum_demand_satisfied_H)-sum(sum(demand_satisfied_H_W)))
  all_C_W_shortage.append(U_R_V*sum(sum_demand_satisfied_C)-sum(sum(demand_satisfied_C_W)))
  all_SH_W_shortage.append(U_R_NV*sum(sum_demand_satisfied_SH)-sum(sum(demand_satisfied_SH_W)))

  all_obj.append(m.objVal)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x13c2e626
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.534649e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.35346    0    4   -0.00000    0.35346      -     -    0s
# H    0     0                       0.2787277    0.35346  26.8%     -    0s
# H    0     0                       0.3326717    0.35346  6.25%     -    0s
# H    0     0                       0.3391706    0.35346  4.21%     -    0s
#      0     0    0.35241    0    8    0.33917    0.35241  3.90%     -    0s
# H    0     0                       0.3436603    0.35241  2.55%     -    0s
# H    0     0                       0.3459153    0.35241  1.88%     -    0s
# H    0     0                       0.3523009    0.35241  0.03%     -    0s
#      0     0     cutoff    0         0.35230    0.35230  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Flow cover: 3
#   Relax-and-lift: 2
#
# Explored 1 nodes (53 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 7: 0.352301 0.345915 0.34366 ... -0
# No other solutions better than 0.352301
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.523008565392e-01, best bound 3.523008565392e-01, gap 0.0000%
# [0.3194971366181951]
# [0.3194971366181951, 0.6281604478177266]
# [0.3194971366181951, 0.6281604478177266, 0.2572814020861157]
# [319.49713662 628.16044782 257.28140209]
# [0.31949714 0.62816045 0.2572814 ]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x04082e56
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.677606e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36776    0    5   -0.00000    0.36776      -     -    0s
# H    0     0                       0.2889754    0.36776  27.3%     -    0s
# H    0     0                       0.3494183    0.36776  5.25%     -    0s
#      0     0    0.36314    0   10    0.34942    0.36314  3.93%     -    0s
#      0     0    0.36262    0    3    0.34942    0.36262  3.78%     -    0s
#      0     0    0.36245    0    2    0.34942    0.36245  3.73%     -    0s
# H    0     0                       0.3547895    0.36245  2.16%     -    0s
# H    0     0                       0.3585651    0.36245  1.08%     -    0s
# H    0     0                       0.3623986    0.36245  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 3
#   Flow cover: 3
#   Relax-and-lift: 3
#
# Explored 1 nodes (59 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.362399 0.358565 0.35479 ... -0
# No other solutions better than 0.362399
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.623986304672e-01, best bound 3.623986304672e-01, gap 0.0000%
# [0.976733846123472]
# [0.976733846123472, 0.9035032691085275]
# [0.976733846123472, 0.9035032691085275, 0.20201158487740345]
# [976.73384612 903.50326911 202.01158488]
# [0.97673385 0.90350327 0.20201158]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xe0f66337
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.394140e-01, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.33941    0    8   -0.00000    0.33941      -     -    0s
# H    0     0                       0.2553049    0.33941  32.9%     -    0s
# H    0     0                       0.3157479    0.33941  7.50%     -    0s
#      0     0    0.33055    0    1    0.31575    0.33055  4.69%     -    0s
# *    0     0               0       0.3303726    0.33037  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 3
#   Flow cover: 2
#   Flow path: 1
#   RLT: 2
#   Relax-and-lift: 2
#
# Explored 1 nodes (59 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 0.330373 0.315748 0.255305 -0
# No other solutions better than 0.330373
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.303726426707e-01, best bound 3.303726426707e-01, gap 0.0000%
# [0.6829938361085449]
# [0.6829938361085449, 0.6294760296542226]
# [0.6829938361085449, 0.6294760296542226, 0.8604501317216922]
# [682.99383611 629.47602965 860.45013172]
# [0.68299384 0.62947603 0.86045013]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xd1cdc5bd
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.276329e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.32763    0    6   -0.00000    0.32763      -     -    0s
# H    0     0                       0.2486195    0.32763  31.8%     -    0s
# H    0     0                       0.3025635    0.32763  8.29%     -    0s
# H    0     0                       0.3090624    0.32763  6.01%     -    0s
#      0     0    0.32492    0    6    0.30906    0.32492  5.13%     -    0s
# H    0     0                       0.3188649    0.32492  1.90%     -    0s
# H    0     0                       0.3190030    0.32492  1.85%     -    0s
# H    0     0                       0.3191411    0.32492  1.81%     -    0s
# H    0     0                       0.3199008    0.32492  1.57%     -    0s
#      0     0    0.32490    0   10    0.31990    0.32490  1.56%     -    0s
#      0     0    0.32419    0    1    0.31990    0.32419  1.34%     -    0s
#      0     0    0.32419    0    1    0.31990    0.32419  1.34%     -    0s
#      0     0    0.32419    0    1    0.31990    0.32419  1.34%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   Flow cover: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (59 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 8: 0.319901 0.319141 0.319003 ... -0
# No other solutions better than 0.319901
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.199008094369e-01, best bound 3.199008094369e-01, gap 0.0000%
# [0.5346316771476609]
# [0.5346316771476609, 0.361767281050686]
# [0.5346316771476609, 0.361767281050686, 0.9775928156545048]
# [534.63167715 361.76728105 977.59281565]
# [0.53463168 0.36176728 0.97759282]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x5700a9f5
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.577409e-01, 51 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.35774    0    4   -0.00000    0.35774      -     -    0s
# H    0     0                       0.2798284    0.35774  27.8%     -    0s
# H    0     0                       0.3337724    0.35774  7.18%     -    0s
# H    0     0                       0.3491229    0.35774  2.47%     -    0s
#      0     0    0.35303    0    1    0.34912    0.35303  1.12%     -    0s
#      0     0     cutoff    0         0.34912    0.34912  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 2
#   Flow cover: 5
#
# Explored 1 nodes (61 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 0.349123 0.333772 0.279828 -0
# No other solutions better than 0.349123
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.491229437680e-01, best bound 3.491229437680e-01, gap 0.0000%
# [0.3599815654725681]
# [0.3599815654725681, 0.982815075851064]
# [0.3599815654725681, 0.982815075851064, 0.44174204591340316]
# [359.98156547 982.81507585 441.74204591]
# [0.35998157 0.98281508 0.44174205]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x4c5a8394
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
#   Gomory: 3
#   Implied bound: 2
#   MIR: 1
#   Flow cover: 5
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (73 simplex iterations) in 0.40 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 7: 0.352896 0.346141 0.346059 ... -0
# No other solutions better than 0.352896
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.528958416646e-01, best bound 3.528958416646e-01, gap 0.0000%
# [0.36497985170400615]
# [0.36497985170400615, 0.6428481794998561]
# [0.36497985170400615, 0.6428481794998561, 0.47867187748781603]
# [364.9798517  642.8481795  478.67187749]
# [0.36497985 0.64284818 0.47867188]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xb85e5fd8
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.673473e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36735    0    6   -0.00000    0.36735      -     -    0s
# H    0     0                       0.2832270    0.36735  29.7%     -    0s
# H    0     0                       0.3436699    0.36735  6.89%     -    0s
# H    0     0                       0.3462982    0.36735  6.08%     -    0s
# H    0     0                       0.3528253    0.36735  4.12%     -    0s
# *    0     0               0       0.3531561    0.35316  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 3
#   MIR: 3
#   Flow cover: 6
#   Mod-K: 1
#
# Explored 1 nodes (59 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.353156 0.352825 0.346298 ... -0
# No other solutions better than 0.353156
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.531561449394e-01, best bound 3.531561449394e-01, gap 0.0000%
# [0.5638228444008186]
# [0.5638228444008186, 0.27017011692213855]
# [0.5638228444008186, 0.27017011692213855, 0.7770639143628831]
# [563.8228444  270.17011692 777.06391436]
# [0.56382284 0.27017012 0.77706391]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x36a113b1
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.671569e-01, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36716    0    8   -0.00000    0.36716      -     -    0s
# H    0     0                       0.2737501    0.36716  34.1%     -    0s
# H    0     0                       0.3341931    0.36716  9.86%     -    0s
#      0     0    0.36181    0    9    0.33419    0.36181  8.26%     -    0s
#      0     0    0.36170    0    8    0.33419    0.36170  8.23%     -    0s
# H    0     0                       0.3522697    0.36170  2.68%     -    0s
# H    0     0                       0.3523547    0.36170  2.65%     -    0s
# H    0     0                       0.3525247    0.36170  2.60%     -    0s
# H    0     0                       0.3545647    0.36170  2.01%     -    0s
# *    0     0               0       0.3615335    0.36153  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   StrongCG: 1
#   Flow cover: 4
#   Relax-and-lift: 4
#
# Explored 1 nodes (60 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 8: 0.361534 0.354565 0.352525 ... -0
# No other solutions better than 0.361534
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.615335157230e-01, best bound 3.615335157230e-01, gap 0.0000%
# [0.39929118727096236]
# [0.39929118727096236, 0.032534359890683096]
# [0.39929118727096236, 0.032534359890683096, 0.24130574995477228]
# [399.29118727  32.53435989 241.30574995]
# [0.39929119 0.03253436 0.24130575]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x91c72c8e
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.237809e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.32378    0    4   -0.00000    0.32378      -     -    0s
# H    0     0                       0.2569168    0.32378  26.0%     -    0s
# H    0     0                       0.3153900    0.32378  2.66%     -    0s
#      0     0    0.31738    0    3    0.31539    0.31738  0.63%     -    0s
#      0     0    0.31661    0    3    0.31539    0.31661  0.39%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Flow cover: 1
#
# Explored 1 nodes (58 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 0.31539 0.256917 -0
# No other solutions better than 0.31539
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.153899645894e-01, best bound 3.153899645894e-01, gap 0.0000%
# [0.030556336246509108]
# [0.030556336246509108, 0.8048714327198674]
# [0.030556336246509108, 0.8048714327198674, 0.6382693480829308]
# [ 30.55633625 804.87143272 638.26934808]
# [0.03055634 0.80487143 0.63826935]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xfde06ff3
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.617288e-01, 51 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36173    0    4   -0.00000    0.36173      -     -    0s
# H    0     0                       0.2874825    0.36173  25.8%     -    0s
# H    0     0                       0.3414264    0.36173  5.95%     -    0s
# H    0     0                       0.3479254    0.36173  3.97%     -    0s
#      0     0    0.35953    0    4    0.34793    0.35953  3.33%     -    0s
#      0     0    0.35935    0    3    0.34793    0.35935  3.28%     -    0s
# H    0     0                       0.3549411    0.35935  1.24%     -    0s
# *    0     0               0       0.3562644    0.35626  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   MIR: 1
#   StrongCG: 1
#   Flow cover: 2
#   Mod-K: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (66 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.356264 0.354941 0.347925 ... -0
# No other solutions better than 0.356264
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.562644205259e-01, best bound 3.562644205259e-01, gap 0.0000%
# [0.36533264697646006]
# [0.36533264697646006, 0.02140470149921536]
# [0.36533264697646006, 0.02140470149921536, 0.7993661164091058]
# [365.33264698  21.4047015  799.36611641]
# [0.36533265 0.0214047  0.79936612]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x5e5a0b3a
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.716344e-01, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.37163    0    5   -0.00000    0.37163      -     -    0s
# H    0     0                       0.2830090    0.37163  31.3%     -    0s
# H    0     0                       0.3434519    0.37163  8.21%     -    0s
# H    0     0                       0.3487260    0.37163  6.57%     -    0s
# H    0     0                       0.3488960    0.37163  6.52%     -    0s
# H    0     0                       0.3622406    0.37163  2.59%     -    0s
#      0     0    0.36406    0    4    0.36224    0.36406  0.50%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Flow cover: 6
#
# Explored 1 nodes (63 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.362241 0.348896 0.348726 ... -0
# No other solutions better than 0.362241
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.622406422981e-01, best bound 3.622406422981e-01, gap 0.0000%
# [0.1611502660374362]
# [0.1611502660374362, 0.945197708494544]
# [0.1611502660374362, 0.945197708494544, 0.35625684945421576]
# [161.15026604 945.19770849 356.25684945]
# [0.16115027 0.94519771 0.35625685]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xc1d4af49
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.710858e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.37109    0    4   -0.00000    0.37109      -     -    0s
# H    0     0                       0.2969708    0.37109  25.0%     -    0s
# H    0     0                       0.3509148    0.37109  5.75%     -    0s
# H    0     0                       0.3670997    0.37109  1.09%     -    0s
#      0     0    0.36802    0    1    0.36710    0.36802  0.25%     -    0s
#      0     0    0.36802    0    2    0.36710    0.36802  0.25%     -    0s
#      0     0    0.36802    0    1    0.36710    0.36802  0.25%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (60 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 0.3671 0.350915 0.296971 -0
# No other solutions better than 0.3671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.670996891597e-01, best bound 3.670996891597e-01, gap 0.0000%
# [0.6862795286856117]
# [0.6862795286856117, 0.007565957697428849]
# [0.6862795286856117, 0.007565957697428849, 0.7367543008925569]
# [686.27952869   7.5659577  736.75430089]
# [0.68627953 0.00756596 0.7367543 ]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x10e68d14
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.672452e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36725    0    6   -0.00000    0.36725      -     -    0s
# H    0     0                       0.2830090    0.36725  29.8%     -    0s
# H    0     0                       0.3369530    0.36725  8.99%     -    0s
# H    0     0                       0.3375024    0.36725  8.81%     -    0s
# H    0     0                       0.3434519    0.36725  6.93%     -    0s
#      0     0    0.35965    0   17    0.34345    0.35965  4.71%     -    0s
#      0     0    0.35882    0   12    0.34345    0.35882  4.47%     -    0s
# H    0     0                       0.3504676    0.35882  2.38%     -    0s
#      0     0    0.35859    0   11    0.35047    0.35859  2.32%     -    0s
#      0     0    0.35859    0   11    0.35047    0.35859  2.32%     -    0s
# *    0     0               0       0.3508471    0.35085  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Implied bound: 1
#   MIR: 4
#   Flow cover: 3
#   Relax-and-lift: 3
#
# Explored 1 nodes (73 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 7: 0.350847 0.350468 0.343452 ... -0
# No other solutions better than 0.350847
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.508470666915e-01, best bound 3.508470666915e-01, gap 0.0000%
# [0.2467282787480719]
# [0.2467282787480719, 0.8013420354294236]
# [0.2467282787480719, 0.8013420354294236, 0.5446775420271827]
# [246.72827875 801.34203543 544.67754203]
# [0.24672828 0.80134204 0.54467754]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xafd91063
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.669449e-01, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36694    0    5   -0.00000    0.36694      -     -    0s
# H    0     0                       0.2898991    0.36694  26.6%     -    0s
# H    0     0                       0.3438430    0.36694  6.72%     -    0s
# H    0     0                       0.3593292    0.36694  2.12%     -    0s
# H    0     0                       0.3594419    0.36694  2.09%     -    0s
# H    0     0                       0.3649668    0.36694  0.54%     -    0s
#      0     0     cutoff    0         0.36497    0.36497  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Flow cover: 2
#
# Explored 1 nodes (61 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.364967 0.359442 0.359329 ... -0
# No other solutions better than 0.364967
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.649667778173e-01, best bound 3.649667778173e-01, gap 0.0000%
# [0.710589867252876]
# [0.710589867252876, 0.6422124686956304]
# [0.710589867252876, 0.6422124686956304, 0.16877875748470494]
# [710.58986725 642.2124687  168.77875748]
# [0.71058987 0.64221247 0.16877876]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xc95ea659
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.665163e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36652    0    6   -0.00000    0.36652      -     -    0s
# H    0     0                       0.2766104    0.36652  32.5%     -    0s
# H    0     0                       0.3370533    0.36652  8.74%     -    0s
#      0     0    0.35510    0   18    0.33705    0.35510  5.35%     -    0s
# H    0     0                       0.3440690    0.35510  3.21%     -    0s
#      0     0    0.35494    0   15    0.34407    0.35494  3.16%     -    0s
#      0     0    0.35491    0   20    0.34407    0.35491  3.15%     -    0s
#      0     0    0.35023    0   21    0.34407    0.35023  1.79%     -    0s
# H    0     0                       0.3457602    0.35023  1.29%     -    0s
#      0     0    0.34992    0   19    0.34576    0.34992  1.20%     -    0s
# H    0     0                       0.3468372    0.34992  0.89%     -    0s
#      0     0    0.34961    0   17    0.34684    0.34961  0.80%     -    0s
#      0     0    0.34952    0   17    0.34684    0.34952  0.77%     -    0s
#      0     0    0.34906    0   26    0.34684    0.34906  0.64%     -    0s
#      0     0    0.34906    0   25    0.34684    0.34906  0.64%     -    0s
#      0     0    0.34906    0   25    0.34684    0.34906  0.64%     -    0s
#      0     0    0.34906    0    1    0.34684    0.34906  0.64%     -    0s
#      0     0    0.34906    0   10    0.34684    0.34906  0.64%     -    0s
#      0     0     cutoff    0         0.34684    0.34684  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 1
#   Flow cover: 1
#
# Explored 1 nodes (105 simplex iterations) in 0.14 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.346837 0.34576 0.344069 ... -0
# No other solutions better than 0.346837
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.468371972704e-01, best bound 3.468371972704e-01, gap 0.0000%
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.625072e-01, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36251    0    6   -0.00000    0.36251      -     -    0s
# H    0     0                       0.2740605    0.36251  32.3%     -    0s
# H    0     0                       0.3280044    0.36251  10.5%     -    0s
# H    0     0                       0.3397163    0.36251  6.71%     -    0s
# H    0     0                       0.3398863    0.36251  6.66%     -    0s
# H    0     0                       0.3530610    0.36251  2.68%     -    0s
#      0     0    0.35320    0    4    0.35306    0.35320  0.04%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Implied bound: 3
#   MIR: 1
#   Flow cover: 7
#
# Explored 1 nodes (67 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.353061 0.339886 0.339716 ... -0
# No other solutions better than 0.353061
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.530610090465e-01, best bound 3.530610090465e-01, gap 0.0000%
# [0.5572238332029325]
# [0.5572238332029325, 0.997452834186486]
# [0.5572238332029325, 0.997452834186486, 0.4565018269334282]
# [557.2238332  997.45283419 456.50182693]
# [0.55722383 0.99745283 0.45650183]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x000c8053
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.462246e-01, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.34622    0    6   -0.00000    0.34622      -     -    0s
# H    0     0                       0.2691485    0.34622  28.6%     -    0s
# H    0     0                       0.3230925    0.34622  7.16%     -    0s
# H    0     0                       0.3295914    0.34622  5.05%     -    0s
#      0     0    0.34327    0    3    0.32959    0.34327  4.15%     -    0s
#      0     0    0.34310    0    2    0.32959    0.34310  4.10%     -    0s
# H    0     0                       0.3362606    0.34310  2.03%     -    0s
#      0     0    0.33892    0    9    0.33626    0.33892  0.79%     -    0s
# *    0     0               0       0.3366071    0.33661  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   MIR: 1
#   Flow cover: 3
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (71 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.336607 0.336261 0.329591 ... -0
# No other solutions better than 0.336607
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.366071401605e-01, best bound 3.366071401605e-01, gap 0.0000%
# [0.15965105202685925]
# [0.15965105202685925, 0.9742714175813691]
# [0.15965105202685925, 0.9742714175813691, 0.9794649066381578]
# [159.65105203 974.27141758 979.46490664]
# [0.15965105 0.97427142 0.97946491]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x6d0a7a5e
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.205915e-01, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.32059    0    3   -0.00000    0.32059      -     -    0s
# H    0     0                       0.2424304    0.32059  32.2%     -    0s
# H    0     0                       0.3059471    0.32059  4.79%     -    0s
#      0     0    0.31314    0    1    0.30595    0.31314  2.35%     -    0s
# *    0     0               0       0.3129628    0.31296  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Flow cover: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (38 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 0.312963 0.305947 0.24243 -0
# No other solutions better than 0.312963
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.129627636012e-01, best bound 3.129627636012e-01, gap 0.0000%
# [0.3894049816047943]
# [0.3894049816047943, 0.128236113569566]
# [0.3894049816047943, 0.128236113569566, 0.8285078074823156]
# [389.4049816  128.23611357 828.50780748]
# [0.38940498 0.12823611 0.82850781]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x90053942
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.725108e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.37251    0    5   -0.00000    0.37251      -     -    0s
# H    0     0                       0.2890238    0.37251  28.9%     -    0s
# H    0     0                       0.3494667    0.37251  6.59%     -    0s
#      0     0    0.36791    0    6    0.34947    0.36791  5.28%     -    0s
#      0     0    0.36519    0    1    0.34947    0.36519  4.50%     -    0s
#      0     0    0.36519    0    1    0.34947    0.36519  4.50%     -    0s
# H    0     0                       0.3527031    0.36519  3.54%     -    0s
# H    0     0                       0.3545413    0.36519  3.00%     -    0s
# *    0     0               0       0.3651034    0.36510  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 1
#   Flow cover: 6
#   Relax-and-lift: 1
#
# Explored 1 nodes (61 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.365103 0.354541 0.352703 ... -0
# No other solutions better than 0.365103
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.651034264753e-01, best bound 3.651034264753e-01, gap 0.0000%
# [0.8563366713466944]
# [0.8563366713466944, 0.05520051333506637]
# [0.8563366713466944, 0.05520051333506637, 0.8348005102119602]
# [856.33667135  55.20051334 834.80051021]
# [0.85633667 0.05520051 0.83480051]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xa21bc5fc
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.574056e-01, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.35741    0    6   -0.00000    0.35741      -     -    0s
# H    0     0                       0.2712645    0.35741  31.8%     -    0s
# H    0     0                       0.3317075    0.35741  7.75%     -    0s
#      0     0    0.35234    0    7    0.33171    0.35234  6.22%     -    0s
#      0     0    0.35054    0    4    0.33171    0.35054  5.68%     -    0s
# H    0     0                       0.3381594    0.35054  3.66%     -    0s
# H    0     0                       0.3382722    0.35054  3.63%     -    0s
# H    0     0                       0.3461003    0.35054  1.28%     -    0s
# H    0     0                       0.3501523    0.35054  0.11%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 2
#   Flow cover: 2
#   Mod-K: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (65 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 7: 0.350152 0.3461 0.338272 ... -0
# No other solutions better than 0.350152
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.501523441752e-01, best bound 3.501523441752e-01, gap 0.0000%
# [0.06489618284463594]
# [0.06489618284463594, 0.4312844525293339]
# [0.06489618284463594, 0.4312844525293339, 0.3714449767176706]
# [ 64.89618284 431.28445253 371.44497672]
# [0.06489618 0.43128445 0.37144498]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x0eb7be11
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.495903e-01, 44 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.34959    0    3   -0.00000    0.34959      -     -    0s
# H    0     0                       0.3395929    0.34959  2.94%     -    0s
# H    0     0                       0.3451762    0.34959  1.28%     -    0s
#      0     0    0.34612    0    1    0.34518    0.34612  0.27%     -    0s
# H    0     0                       0.3453413    0.34612  0.23%     -    0s
#      0     0    0.34612    0    1    0.34534    0.34612  0.23%     -    0s
#
# Explored 1 nodes (63 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 0.345341 0.345176 0.339593 -0
# No other solutions better than 0.345341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.453412741673e-01, best bound 3.453412741673e-01, gap 0.0000%
# [0.3327243590513028]
# [0.3327243590513028, 0.8850099710949643]
# [0.3327243590513028, 0.8850099710949643, 0.3065535532926261]
# [332.72435905 885.00997109 306.55355329]
# [0.33272436 0.88500997 0.30655355]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xf32dabf7
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
# ...
# H    0     0                       0.3498174    0.35829  2.42%     -    0s
#      0     0    0.35789    0   14    0.34982    0.35789  2.31%     -    0s
#      0     0    0.35172    0   24    0.34982    0.35172  0.54%     -    0s
#      0     0    0.35172    0   24    0.34982    0.35172  0.54%     -    0s
#      0     0    0.35056    0   14    0.34982    0.35056  0.21%     -    0s
#      0     0    0.35026    0   11    0.34982    0.35026  0.13%     -    0s
#      0     0    0.35017    0   12    0.34982    0.35017  0.10%     -    0s
# *    0     0               0       0.3501483    0.35015  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 1
#   Implied bound: 1
#   MIR: 5
#   StrongCG: 1
#   Flow cover: 4
#   Relax-and-lift: 2
#
# Explored 1 nodes (82 simplex iterations) in 0.14 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 5: 0.350148 0.349817 0.337053 ... -0
# No other solutions better than 0.350148
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.501482686982e-01, best bound 3.501482686982e-01, gap 0.0000%
# [0.3045323682300508]
# [0.3045323682300508, 0.15056803893512627]
# [0.3045323682300508, 0.15056803893512627, 0.06543109217673082]
# [304.53236823 150.56803894  65.43109218]
# [0.30453237 0.15056804 0.06543109]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xe871e115
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 2.983715e-01, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.29837    0    7   -0.00000    0.29837      -     -    0s
# H    0     0                       0.2222598    0.29837  34.2%     -    0s
# H    0     0                       0.2511132    0.29837  18.8%     -    0s
# H    0     0                       0.2657031    0.29837  12.3%     -    0s
#      0     0    0.29391    0    2    0.26570    0.29391  10.6%     -    0s
# H    0     0                       0.2859525    0.29391  2.78%     -    0s
#      0     0    0.28732    0   26    0.28595    0.28732  0.48%     -    0s
#      0     0    0.28700    0   17    0.28595    0.28700  0.37%     -    0s
#      0     0    0.28667    0    7    0.28595    0.28667  0.25%     -    0s
#      0     0    0.28634    0    1    0.28595    0.28634  0.14%     -    0s
# *    0     0               0       0.2861836    0.28618  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Implied bound: 2
#   MIR: 1
#   Flow cover: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (84 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.286184 0.285953 0.265703 ... -0
# No other solutions better than 0.286184
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.861836103988e-01, best bound 2.861836103988e-01, gap 0.0000%
# [0.48425150234226677]
# [0.48425150234226677, 0.7168916720927995]
# [0.48425150234226677, 0.7168916720927995, 0.5743558451968361]
# [484.25150234 716.89167209 574.3558452 ]
# [0.4842515  0.71689167 0.57435585]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x4d175e81
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.590286e-01, 51 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.35903    0    6   -0.00000    0.35903      -     -    0s
# H    0     0                       0.2766822    0.35903  29.8%     -    0s
# H    0     0                       0.3371251    0.35903  6.50%     -    0s
#      0     0    0.35136    0    3    0.33713    0.35136  4.22%     -    0s
# H    0     0                       0.3446883    0.35136  1.94%     -    0s
# H    0     0                       0.3454086    0.35136  1.72%     -    0s
#      0     0    0.35011    0    1    0.34541    0.35011  1.36%     -    0s
# H    0     0                       0.3469238    0.35011  0.92%     -    0s
#      0     0    0.34811    0    8    0.34692    0.34811  0.34%     -    0s
#      0     0    0.34811    0    4    0.34692    0.34811  0.34%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 4
#   Flow cover: 4
#   RLT: 2
#   Relax-and-lift: 2
#
# Explored 1 nodes (74 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 6: 0.346924 0.345409 0.344688 ... -0
# No other solutions better than 0.346924
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.469238155376e-01, best bound 3.469238155376e-01, gap 0.0000%
# [0.8981479925380934]
# [0.8981479925380934, 0.48171363069601303]
# [0.8981479925380934, 0.48171363069601303, 0.15070770775403652]
# [898.14799254 481.7136307  150.70770775]
# [0.89814799 0.48171363 0.15070771]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xb2323a2a
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.677550e-01, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36775    0    4   -0.00000    0.36775      -     -    0s
# H    0     0                       0.2842749    0.36775  29.4%     -    0s
# H    0     0                       0.3447179    0.36775  6.68%     -    0s
#      0     0    0.36052    0    1    0.34472    0.36052  4.58%     -    0s
# *    0     0               0       0.3603453    0.36035  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 2
#   Flow cover: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (56 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 0.360345 0.344718 0.284275 -0
# No other solutions better than 0.360345
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.603452717427e-01, best bound 3.603452717427e-01, gap 0.0000%
# [0.5970785643067009]
# [0.5970785643067009, 0.39936446461349395]
# [0.5970785643067009, 0.39936446461349395, 0.6446189107283434]
# [597.07856431 399.36446461 644.61891073]
# [0.59707856 0.39936446 0.64461891]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x67a8c92b
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.652511e-01, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36525    0    7   -0.00000    0.36525      -     -    0s
# H    0     0                       0.2839212    0.36525  28.6%     -    0s
# H    0     0                       0.3378651    0.36525  8.11%     -    0s
# H    0     0                       0.3418032    0.36525  6.86%     -    0s
# H    0     0                       0.3443641    0.36525  6.07%     -    0s
#      0     0    0.36274    0    2    0.34436    0.36274  5.34%     -    0s
# H    0     0                       0.3522011    0.36274  2.99%     -    0s
# H    0     0                       0.3534825    0.36274  2.62%     -    0s
#      0     0    0.35927    0    2    0.35348    0.35927  1.64%     -    0s
# *    0     0               0       0.3589889    0.35899  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 4
#   Flow cover: 8
#   Zero half: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (66 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 8: 0.358989 0.353483 0.352201 ... -0
# No other solutions better than 0.358989
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.589888891212e-01, best bound 3.589888891212e-01, gap 0.0000%
# [0.3141199227493625]
# [0.3141199227493625, 0.49972615427892964]
# [0.3141199227493625, 0.49972615427892964, 0.8926759509565337]
# [314.11992275 499.72615428 892.67595096]
# [0.31411992 0.49972615 0.89267595]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x1a978754
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.654409e-01, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36544    0    5   -0.00000    0.36544      -     -    0s
# H    0     0                       0.2898253    0.36544  26.1%     -    0s
# H    0     0                       0.3437692    0.36544  6.30%     -    0s
# H    0     0                       0.3643535    0.36544  0.30%     -    0s
#      0     0    0.36443    0    1    0.36435    0.36443  0.02%     -    0s
#      0     0    0.36443    0    1    0.36435    0.36443  0.02%     -    0s
#      0     0    0.36443    0    1    0.36435    0.36443  0.02%     -    0s
#      0     0     cutoff    0         0.36435    0.36435  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#
# Explored 1 nodes (74 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 0.364353 0.343769 0.289825 -0
# No other solutions better than 0.364353
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.643534697967e-01, best bound 3.643534697967e-01, gap 0.0000%
# [0.07129010175345452]
# [0.07129010175345452, 0.20661649150610417]
# [0.07129010175345452, 0.20661649150610417, 0.6001398946594313]
# [ 71.29010175 206.61649151 600.13989466]
# [0.0712901  0.20661649 0.60013989]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0x41990969
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]
#   QObjective range [1e-04, 1e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 74 columns, 161 nonzeros
# Variable types: 0 continuous, 74 integer (35 binary)
#
# Root relaxation: objective 3.512109e-01, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.35121    0    2   -0.00000    0.35121      -     -    0s
# H    0     0                       0.3475142    0.35121  1.06%     -    0s
#      0     0    0.34945    0    1    0.34751    0.34945  0.56%     -    0s
#      0     0    0.34945    0    1    0.34751    0.34945  0.56%     -    0s
# *    0     0               0       0.3483471    0.34835  0.00%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 0.348347 0.347514 -0
# No other solutions better than 0.348347
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.483471327238e-01, best bound 3.483471327238e-01, gap 0.0000%
# [0.04930847108832481]
# [0.04930847108832481, 0.8570912196728334]
# [0.04930847108832481, 0.8570912196728334, 0.5332674036156836]
# [ 49.30847109 857.09121967 533.26740362]
# [0.04930847 0.85709122 0.5332674 ]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 55 rows, 74 columns and 118 nonzeros
# Model fingerprint: 0xb25ac1c0
# Model has 30 quadratic objective terms
# Model has 36 quadratic constraints
# Variable types: 0 continuous, 74 integer (38 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-03, 2e-02]

# %% [markdown]
# # **The Results**

# %% [markdown]
# Average of objectives values along the 10,000 scenarios

# %% [markdown]
# Average of victims' demand shortage values along the 10,000 scenarios

# %%
average_obj = sum(all_obj)/S
average_obj
# Out:
# 0.3415998915406872

# %%
av_V_shortage = int(sum(all_V_shortage)/S)
print(len(all_V_shortage))
av_V_shortage
# Out:
# 10000
# 490

# %% [markdown]
# Average of non-victims' demand shortage values along the 10,000 scenarios

# %%
av_NV_shortage = int(sum(all_NV_shortage)/S)
av_NV_shortage
# Out:
# 337

# %% [markdown]
# Average of hospitals' demand shortage values along the 10,000 scenarios

# %%
av_H_W_shortage = int(sum(all_H_W_shortage)/S)
av_H_W_shortage
# Out:
# 551

# %% [markdown]
# Average of centers' demand shortage values along the 10,000 scenarios

# %%
av_C_W_shortage = int(sum(all_C_W_shortage)/S)
av_C_W_shortage
# Out:
# 187

# %% [markdown]
# Average of shelters' demand shortage values along the 10,000 scenarios

# %%
av_SH_W_shortage = int(sum(all_SH_W_shortage)/S)
av_SH_W_shortage
# Out:
# 761

# %% [markdown]
# The average of the usage of each hospital through all scenarios

# %%
all_hospitals = np.array(all_hospitals).reshape(S, num_hospitals)
usage_of_hospital = []
for j in range(0, num_hospitals):
  usage_of_hospital.append(int((sum(all_hospitals[:,j])/S)*100))
usage_of_hospital
# Out:
# [98, 86]

# %% [markdown]
# The average of the usage of each center through all scenarios

# %%
all_centers = np.array(all_centers).reshape(S, num_centers)
usage_of_center = []
for j in range(0, num_centers):
  usage_of_center.append(int((sum(all_centers[:,j])/S)*100))
usage_of_center
# Out:
# [99, 0]

# %% [markdown]
# The average of the usage of each shelter through all scenarios

# %%
all_shelters = np.array(all_shelters).reshape(S, num_shelters)
usage_of_shelter = []
for j in range(0, num_shelters):
  usage_of_shelter.append(int((sum(all_shelters[:,j])/S)*100))
usage_of_shelter
# Out:
# [99, 92]

# %% [markdown]
# The average of the usage of each warehouse through all scenarios

# %%
all_warehouses = np.array(all_warehouses).reshape(S, num_warehouses)
usage_of_warehouse = []
for j in range(0, num_warehouses):
  usage_of_warehouse.append(int((sum(all_warehouses[:,j])/S)*100))
usage_of_warehouse
# Out:
# [100, 100]

# %% [markdown]
# The average of demand satisfied by each hospital through all scenarios

# %%
all_demand_satisfied_H = np.array(all_demand_satisfied_H).reshape(num_hospitals*S, num_nodes)
demand_H = []
for i in range(0, num_hospitals):
  H_x = []
  for j in range(i, num_hospitals*S, num_hospitals):
    H_x.append(sum(all_demand_satisfied_H[j]))
  demand_H.append(int(sum(H_x)/S))
demand_H
# Out:
# [715, 195]

# %% [markdown]
# The average of demand satisfied by each center through all scenarios

# %%
all_demand_satisfied_C = np.array(all_demand_satisfied_C).reshape(num_centers*S, num_nodes)
demand_C = []
for i in range(0, num_centers):
  C_x = []
  for j in range(i, num_centers*S, num_centers):
    C_x.append(sum(all_demand_satisfied_C[j]))
  demand_C.append(int(sum(C_x)/S))
demand_C
# Out:
# [99, 0]

# %% [markdown]
# The average of demand satisfied by each shelter through all scenarios

# %%
all_demand_satisfied_SH = np.array(all_demand_satisfied_SH).reshape(num_shelters*S, num_nodes)
demand_SH = []
for i in range(0, num_shelters):
  SH_x = []
  for j in range(i, num_shelters*S, num_shelters):
    SH_x.append(sum(all_demand_satisfied_SH[j]))
  demand_SH.append(int(sum(SH_x)/S))
demand_SH
# Out:
# [653, 504]

# %% [markdown]
# The average of hospitals' demand satisfied by each warehouse through all scenarios

# %%
all_demand_satisfied_H_W = np.array(all_demand_satisfied_H_W).reshape(num_warehouses*S, num_hospitals)
demand_H_W = []
for i in range(0, num_warehouses):
  W_H_x = []
  for j in range(i, num_warehouses*S, num_warehouses):
    W_H_x.append(sum(all_demand_satisfied_H_W[j]))
  demand_H_W.append(int(sum(W_H_x)/S))
demand_H_W
# Out:
# [286, 984]

# %% [markdown]
# The average of centers' demand satisfied by each warehouse through all scenarios

# %%
all_demand_satisfied_C_W = np.array(all_demand_satisfied_C_W).reshape(num_warehouses*S, num_centers)
demand_C_W = []
for i in range(0, num_warehouses):
  W_C_x = []
  for j in range(i, num_warehouses*S, num_warehouses):
    W_C_x.append(sum(all_demand_satisfied_C_W[j]))
  demand_C_W.append(int(sum(W_C_x)/S))
demand_C_W
# Out:
# [2, 8]

# %% [markdown]
# The average of shelters' demand satisfied by each warehouse through all scenarios

# %%
all_demand_satisfied_SH_W = np.array(all_demand_satisfied_SH_W).reshape(num_warehouses*S, num_shelters)
demand_SH_W = []
for i in range(0, num_warehouses):
  W_SH_x = []
  for j in range(i, num_warehouses*S, num_warehouses):
    W_SH_x.append(sum(all_demand_satisfied_SH_W[j]))
  demand_SH_W.append(int(sum(W_SH_x)/S))
demand_SH_W
# Out:
# [989, 565]

# %% [markdown]
# Percentage of assigning each disaster zone to each hospital

# %%
av_assigned_H = all_nodes_assigned_H[0]
for j in range(1, S):
  av_assigned_H = av_assigned_H + all_nodes_assigned_H[j]
av_assigned_H = (av_assigned_H/S)*100
av_assigned_H = np.array(av_assigned_H).astype(int)
av_assigned_H
# Out:
# array([[27, 46, 51],
#        [40, 41,  3]])

# %% [markdown]
# Percentage of assigning each disaster zone to each center

# %%
av_assigned_C = all_nodes_assigned_C[0]
for j in range(1, S):
  av_assigned_C = av_assigned_C + all_nodes_assigned_C[j]
av_assigned_C = (av_assigned_C/S)*100
av_assigned_C = np.array(av_assigned_C).astype(int)
av_assigned_C
# Out:
# array([[ 0, 21, 77],
#        [ 0,  0,  0]])

# %% [markdown]
# Percentage of assigning each disaster zone to each shelter

# %%
av_assigned_SH = all_nodes_assigned_SH[0]
for j in range(1, S):
  av_assigned_SH = av_assigned_SH + all_nodes_assigned_SH[j]
av_assigned_SH = (av_assigned_SH/S)*100
av_assigned_SH = np.array(av_assigned_SH).astype(int)
av_assigned_SH
# Out:
# array([[72, 16, 48],
#        [ 0, 70, 38]])

# %% [markdown]
# Percentage of assigning each hospital to each warehouse

# %%
av_assigned_H_W = all_nodes_assigned_H_W[0]
for j in range(1, S):
  av_assigned_H_W = av_assigned_H_W + all_nodes_assigned_H_W[j]
av_assigned_H_W = (av_assigned_H_W/S)*100
av_assigned_H_W = np.array(av_assigned_H_W).astype(int)
av_assigned_H_W
# Out:
# array([[ 9, 84],
#        [98,  1]])

# %% [markdown]
# Percentage of assigning each center to each warehouse

# %%
av_assigned_C_W = all_nodes_assigned_C_W[0]
for j in range(1, S):
  av_assigned_C_W = av_assigned_C_W + all_nodes_assigned_C_W[j]
av_assigned_C_W = (av_assigned_C_W/S)*100
av_assigned_C_W = np.array(av_assigned_C_W).astype(int)
av_assigned_C_W
# Out:
# array([[1, 0],
#        [4, 0]])

# %% [markdown]
# Percentage of assigning each shelter to each warehouse

# %%
av_assigned_SH_W = all_nodes_assigned_SH_W[0]
for j in range(1, S):
  av_assigned_SH_W = av_assigned_SH_W + all_nodes_assigned_SH_W[j]
av_assigned_SH_W = (av_assigned_SH_W/S)*100
av_assigned_SH_W = np.array(av_assigned_SH_W).astype(int)
av_assigned_SH_W
# Out:
# array([[98,  0],
#        [ 0, 92]])
