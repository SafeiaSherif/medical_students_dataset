# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from google.colab import drive
import os

# %%
# import my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_b = pd.read_csv('/content/drive/MyDrive/Feasible_filtered_solutions/feasible_filtered_solutions1b')
df_b
# Out:
#      Unnamed: 0  obj1  obj2  obj3  obj4  obj5
# 0             0     0    99     0    81     3
# 1             1    50   145     0    23     5
# 2             2   100   145     0    15     5
# 3             3     0    48     0    12     6
# 4             4     0    48     0    12     6
# ..          ...   ...   ...   ...   ...   ...
# 662         662    50    53   300   133     7
# 663         663     0   197     0   181     4
# 664         664    50   110   100    76     7
# 665         665    50    53   250   136     7
# 666         666     0   108   100   138     7
#
# [667 rows x 6 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/Feasible_filtered_solutions/feasible_filtered_solutions1')
df
# Out:
#       Unnamed: 0  obj1  obj2  obj3  obj4  obj5
# 0              0    50  -169    50  -175    -7
# 1              1   150  -165   150  -232    -7
# 2              2   200  -159   200  -224    -7
# 3              3   100  -114   100  -232    -7
# 4              4   100  -113    50  -232    -7
# ...          ...   ...   ...   ...   ...   ...
# 2124        2124    50  -149     0   -52    -3
# 2125        2125   100  -197   350   -88    -7
# 2126        2126   150  -182   100   -64    -7
# 2127        2127    50  -198   200   -71    -6
# 2128        2128     0  -164    50   -59    -4
#
# [2129 rows x 6 columns]

# %%
df['obj2'] = -1*df['obj2']
df['obj4'] = -1*df['obj4']
df['obj5'] = -1*df['obj5']

# %%
df_b['obj2'] = -1*df_b['obj2']
df_b['obj4'] = -1*df_b['obj4']
df_b['obj5'] = -1*df_b['obj5']

# %%
figb = px.scatter_3d(df_b, x='obj5',
                    y='obj2',
                    z='obj3',
                    size='obj1',
                    color='obj4')
figb.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df, x='obj5',
                    y='obj2',
                    z='obj3',
                    size='obj1',
                    color='obj4')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
! pip install aspose.slides
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 8.4 MB/s eta 0:00:00
# ...

# %%
# !pip install chart_studio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install cufflinks
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import chart_studio
import chart_studio.plotly as py
import chart_studio.tools as tls

# %%
username = 'Safeia'
api_key = 'C6ULIsOmGk4KpB19hvEs'
tls.set_credentials_file(username,api_key)

# %%
# plot2=px.scatter(x=df['obj5'], y=df['obj2'])
# py.plot(plot2,filename='test figure',auto_open=True)
# Out:
# 'https://plotly.com/~Safeia/2/'

# %%
# plot2.write_html("/content/plotx.html")

# %%
fig = px.scatter_3d(df, x='obj5',
                    y='obj2',
                    z='obj3',
                    size='obj1',
                    color='obj4')

py.plot(fig,filename='Pareto plot',auto_open=True)
# Out:
# 'https://plotly.com/~Safeia/4/'

# %%
fig.write_html("/content/Pareto_plot.html")

# %% [markdown]
# # **Example 2 Pareto Plot**

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Feasible_filtered_solutions/feasible_filtered_solutions2')
df2
# Out:
#      Unnamed: 0  obj1  obj2  obj3  obj4  obj5
# 0             0  1500  -593  1400  -511   -13
# 1             1  1350  -593  1450  -511   -13
# 2             2  1000  -463   300  -403   -13
# 3             3  1550  -593  1450  -511   -13
# 4             4  1350  -588  1450  -457   -13
# ..          ...   ...   ...   ...   ...   ...
# 695         695   950  -396   650  -270   -13
# 696         696   950  -396   650  -253   -13
# 697         697   800  -393   900  -286   -13
# 698         698  1000  -423   900  -309   -13
# 699         699  1000  -423   900  -309   -13
#
# [700 rows x 6 columns]

# %%
df2['obj2'] = -1*df2['obj2']
df2['obj4'] = -1*df2['obj4']
df2['obj5'] = -1*df2['obj5']

# %%
fig2 = px.scatter_3d(df2, x='obj5',
                    y='obj2',
                    z='obj3',
                    size='obj1',
                    color='obj4')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.scatter_3d(df2, x='obj5',
                    y='obj2',
                    z='obj3',
                    size='obj1',
                    color='obj4')

py.plot(fig2,filename='Pareto plot2',auto_open=True)
# Out:
# 'https://plotly.com/~Safeia/6/'

# %%
fig2.write_html("/content/Pareto_plot2.html")

# %% [markdown]
# # **Example 3 Pareto Plot**

# %%
df3 = pd.read_csv('/content/drive/MyDrive/feasible_filtered_solutions3')
df3
# Out:
#      Unnamed: 0  obj1  obj2  obj3  obj4  obj5
# 0             0  1850  -710  2150 -1186   -24
# 1             1  1650  -761  2200 -1021   -22
# 2             2  1700  -761  2050 -1021   -22
# 3             3  1900  -774  3200 -1117   -24
# 4             4  1250  -710  2200 -1186   -24
# ..          ...   ...   ...   ...   ...   ...
# 624         624  2250  -800  2350 -1007   -22
# 625         625  2250  -800  2350 -1007   -22
# 626         626  2300  -800  2300 -1007   -22
# 627         627  2000  -800  2500 -1007   -22
# 628         628  2150  -800  2450 -1007   -22
#
# [629 rows x 6 columns]

# %%
df3['obj2'] = -1*df3['obj2']
df3['obj4'] = -1*df3['obj4']
df3['obj5'] = -1*df3['obj5']

# %%
fig3 = px.scatter_3d(df3, x='obj5',
                    y='obj2',
                    z='obj3',
                    size='obj1',
                    color='obj4')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.scatter_3d(df3, x='obj5',
                    y='obj2',
                    z='obj3',
                    size='obj1',
                    color='obj4')

py.plot(fig3,filename='Pareto plot3',auto_open=True)
# Out:
# 'https://plotly.com/~Safeia/9/'

# %%
fig3.write_html("/content/Pareto_plot3.html")
